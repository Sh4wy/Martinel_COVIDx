# %% [markdown]
# # Creating the dataset for the training
#
# ---
# **USEFUL LINKS :**
#
# The paper and its github :
#
# https://github.com/lindawangg/COVID-Net
#
# ---

# %%
# !pip install pydicom
# !pip install "torch==1.4" "torchvision==0.5.0" # to avoid a warning spam
# Out:
# Requirement already satisfied: torch==1.4 in /usr/local/lib/python3.6/dist-packages (1.4.0)
# Requirement already satisfied: torchvision==0.5.0 in /usr/local/lib/python3.6/dist-packages (0.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (1.18.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (7.0.0)

# %%
# IMPORTS :
from fastai.vision import *

import pandas as pd
import csv

from sklearn.utils import shuffle
from sklearn.model_selection import StratifiedShuffleSplit


print( "Using GPU: " + str(torch.cuda.get_device_name() ) )
# Out:
# Using GPU: Tesla K80

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Unzip CovidX-v4 dataset
# !unzip -q '/content/drive/My Drive/Colab Notebooks/Internship/COVID19_DATA/Covid-X-v4.zip'

print('Done!')
# Out:
# replace data/test_split.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: Done!

# %%
# path = Path('drive/My Drive/Colab Notebooks/Internship/COVID19_DATA/covidx')

# # import pandas as pd

# df = pd.read_csv(path/'train_split_v3.txt', sep = ' ', header = None, usecols = [1, 2])
# df.head()

# %% [markdown]
# Old Version

# %%
# path = Path('drive/My Drive/Colab Notebooks/Internship/COVID19_DATA/covidx')

# tfms = get_transforms(flip_vert=True, max_lighting=0.1, max_rotate=None, max_warp=None, max_zoom=1.0)

# data = (ImageDataBunch.from_df(path, df=df, folder='train',fn_col=0, label_col=1)
#         .split_by_rand_pct(valid_pct = 0.2)     
#         .label_from_df() # 'train_split_v3.txt', sep=' ', header = None, fn_col=1, label_col=2
#         .transform(tfms= None, size=448)
#         .databunch(bs = 16)
#         .normalize(imagenet_stats))

# %% [markdown]
# New version

# %%
import pathlib
path = pathlib.Path( '/content/data' )
path.ls()

bs = 30

seed = 42
np.random.seed( seed )

train_path = pathlib.Path( '/content/data/train/' )
test_path = pathlib.Path( '/content/data/test/' )

train = pd.read_csv(path/"train_split.txt", sep=' ', header=None, names=['Image','Class','Origin']).drop('Origin',axis=1)
test = pd.read_csv(path/"test_split.txt", sep=' ', header=None, names=['Image','Class', 'Origin']).drop('Origin',axis=1)

cv = StratifiedShuffleSplit(n_splits=2, test_size=0.1, random_state=seed)
train_idx, val_idx = next(cv.split(train['Image'],train['Class']))

data = (ImageList.from_df(train, path = train_path)
                .split_by_idxs(train_idx.tolist(), val_idx.tolist())
                .label_from_df(cols=['Class'])
                .transform(tfms=get_transforms(max_warp=0.), size=224) 
                .add_test(ImageList.from_df(test, path=test_path))
                .databunch(bs=bs, num_workers = 4)
                .normalize(imagenet_stats)
               )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-2bc033a22903> in <module>()
#       1 import pathlib
#       2 path = pathlib.Path( '/content/data' )
# ----> 3 path.ls()
#       4
#       5 bs = 30
#
# AttributeError: 'PosixPath' object has no attribute 'ls'

# %%
print(data.classes)

data.show_batch(rows=3, figsize=(15,15))
# Out:
# ['COVID-19', 'normal', 'pneumonia']

# %%
train
# Out:
#                                                                                   Image      Class
# 3                                     SARS-10.1148rg.242035193-g04mr34g0-Fig8a-day0....  pneumonia
# 3                                     SARS-10.1148rg.242035193-g04mr34g0-Fig8b-day5....  pneumonia
# 3                                     SARS-10.1148rg.242035193-g04mr34g0-Fig8c-day10...  pneumonia
# 7                                     SARS-10.1148rg.242035193-g04mr34g04a-Fig4a-day...  pneumonia
# 7                                     SARS-10.1148rg.242035193-g04mr34g04b-Fig4b-day...  pneumonia
# ...                                                                                 ...        ...
# c1628c47-5ba3-42dd-8df3-7ad3abd57ad0           c1628c47-5ba3-42dd-8df3-7ad3abd57ad0.png  pneumonia
# c1cddf32-b957-4753-acaa-472ab1447e86           c1cddf32-b957-4753-acaa-472ab1447e86.png  pneumonia
# c1e73a4e-7afe-4ec5-8af6-ce8315d7a2f2           c1e73a4e-7afe-4ec5-8af6-ce8315d7a2f2.png  pneumonia
# c1ec14ff-f6d7-4b38-b0cb-fe07041cbdc8           c1ec14ff-f6d7-4b38-b0cb-fe07041cbdc8.png  pneumonia
# c1f7889a-9ea9-4acb-b64c-b737c929599a           c1f7889a-9ea9-4acb-b64c-b737c929599a.png  pneumonia
#
# [13892 rows x 2 columns]

# %% [markdown]
# # Creating the model

# %%
# !git clone https://github.com/sdoria/mish
# Out:
# fatal: destination path 'mish' already exists and is not an empty directory.

# %%
# %cd mish
from mish import *
from mxresnet import *
# Out:
# /content/mish
# Mish activation loaded...

# %%
from fastai.callbacks import *

learn = Learner(data, mxresnet101(c_out=len(data.classes), sa=True), metrics=[error_rate, accuracy, Precision(), Recall()], callback_fns=[OverSamplingCallback] )

# #If we want to know the learning rate :
# learn.lr_find()
# learn.recorder.plot()

# %% [markdown]
# First round of learning

# %%
from fastai.callbacks import SaveModelCallback
lr = 9e-4 # using lr_find, we choose lr_max not too close from min

# Set up the learning rate (controls the step size)
learn.fit_one_cycle(10, max_lr=lr, callbacks=[ShowGraph(learn), SaveModelCallback(learn, every='improvement', monitor='accuracy',name='model')])  # epoch = number of cycle during the training : forw & backw
learn.save('mxresnet101_v6s1' , return_path=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.567472</td>
#       <td>0.715244</td>
#       <td>0.287050</td>
#       <td>0.712950</td>
#       <td>0.600664</td>
#       <td>0.762758</td>
#       <td>21:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.408644</td>
#       <td>0.972411</td>
#       <td>0.271223</td>
#       <td>0.728777</td>
#       <td>0.634378</td>
#       <td>0.762730</td>
#       <td>22:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.299998</td>
#       <td>0.450802</td>
#       <td>0.170504</td>
#       <td>0.829497</td>
#       <td>0.800665</td>
#       <td>0.845893</td>
#       <td>22:46</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.273389</td>
#       <td>0.244040</td>
#       <td>0.083453</td>
#       <td>0.916547</td>
#       <td>0.903460</td>
#       <td>0.912099</td>
#       <td>22:51</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.207560</td>
#       <td>0.247508</td>
#       <td>0.094964</td>
#       <td>0.905036</td>
#       <td>0.893358</td>
#       <td>0.916008</td>
#       <td>22:55</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.182460</td>
#       <td>0.231011</td>
#       <td>0.079856</td>
#       <td>0.920144</td>
#       <td>0.927737</td>
#       <td>0.911939</td>
#       <td>22:50</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.160034</td>
#       <td>0.198949</td>
#       <td>0.069784</td>
#       <td>0.930216</td>
#       <td>0.921902</td>
#       <td>0.937376</td>
#       <td>22:29</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.126947</td>
#       <td>0.177782</td>
#       <td>0.061151</td>
#       <td>0.938849</td>
#       <td>0.943344</td>
#       <td>0.942835</td>
#       <td>23:04</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.117487</td>
#       <td>0.162233</td>
#       <td>0.049640</td>
#       <td>0.950360</td>
#       <td>0.960282</td>
#       <td>0.948950</td>
#       <td>22:35</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.107036</td>
#       <td>0.162341</td>
#       <td>0.053237</td>
#       <td>0.946763</td>
#       <td>0.964647</td>
#       <td>0.946089</td>
#       <td>22:41</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/fastai/metrics.py:191: UserWarning: average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.
#   warn("average=`binary` was selected for a non binary case. Value for average has now been set to `macro` instead.")
# Better model found at epoch 0 with accuracy value: 0.7129496335983276.
# Better model found at epoch 1 with accuracy value: 0.7287769913673401.
# Better model found at epoch 2 with accuracy value: 0.8294965028762817.
# Better model found at epoch 3 with accuracy value: 0.9165467619895935.
# Better model found at epoch 5 with accuracy value: 0.9201439023017883.
# Better model found at epoch 6 with accuracy value: 0.9302158355712891.
# Better model found at epoch 7 with accuracy value: 0.9388489127159119.
# Better model found at epoch 8 with accuracy value: 0.9503597021102905.
# PosixPath('/content/data/train/models/mxresnet101_v6s1.pth')

# %% [markdown]
# Second round of learning

# %%
# lr2 = lr/3

# # Set up the learning rate (controls the step size)
# learn.fit_one_cycle(4, max_lr=lr2, callbacks=[ShowGraph(learn), SaveModelCallback(learn, every='improvement', monitor='accuracy',name='model')])  # epoch = number of cycle during the training : forw & backw
# learn.save('mxresnet101_v2s2' , return_path=True)

# %% [markdown]
# Let's see some of the most incorrect images, we also compute accuracy and error rate although the ones we will use are the ones computed with the test data.

# %%
# What are the most incorrect ones?

interp = ClassificationInterpretation.from_learner(learn)
interp.plot_top_losses(16, figsize=(15,15)) # multi label version
# # Confusion matrix to compare the results :
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)  

probs,val_labels = learn.get_preds(ds_type=DatasetType.Valid) 
print('Accuracy',accuracy(probs,val_labels)),
print('Error Rate', error_rate(probs, val_labels))
# Out:
# Accuracy tensor(0.9504)
# Error Rate tensor(0.0496)

# %% [markdown]
# # Show + test

# %% [markdown]
# Old version (issues with the number of images in the end) (???)

# %%
# df_test = pd.read_csv(path/'test_split_v3.txt', sep = ' ', header = None, usecols = [1, 2])
# df_test.head()

#  data_test = (ImageDataBunch.from_df(path, df=df_test, folder='test',fn_col=0, label_col=1)
#         .split_none()    
#         .label_from_df()) 

# data_test.valid = data_test.train

# data_test = (data_test.transform(tfms = None, size=448)
        # .databunch(bs = 16))
        # .normalize(imagenet_stats))

# %% [markdown]
# New version adapted from COVIDX-Fastai-XResNet18.ipynb

# %%
data_test = (ImageList.from_df(test, path=test_path)
            .split_none()
            .label_from_df(cols=['Class'])
            .transform(tfms=None, size=224)
            )

data_test.valid = data_test.train
data_test = data_test.databunch(bs=bs, num_workers=4).normalize(imagenet_stats)

# %%
# # If need to load a different model :
# mod = models.densenet169
# learn = cnn_learner(data_test, mod, metrics=[accuracy])

# learn = learn.load(Path('Densenet169_v1s2'))

learn.data.valid_dl = data_test.valid_dl

# Interpret
interp = ClassificationInterpretation.from_learner(learn)

# %% [markdown]
# Let's see the most incorrect images

# %%
# What are the most incorrect ones?
interp.plot_top_losses(16, figsize=(15,15)) # multi label version
# # Confusion matrix to compare the results :
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)  

probs,val_labels = learn.get_preds(ds_type=DatasetType.Valid)

print('Accuracy',accuracy(probs,val_labels)),
print('Error Rate', error_rate(probs, val_labels))
# Out:
# Accuracy tensor(0.9430)
# Error Rate tensor(0.0570)

# %% [markdown]
# Compute the recall and the Precision per class:

# %%
# adapted from COVIDX-Fastai-XResNet18.ipynb
# Convert dataframe test labels to list
gt = test['Class'].tolist()

# Convert from label names to class index values (0, 1, 2)
from sklearn import preprocessing
labels = data.classes
le = preprocessing.LabelEncoder()
targets = le.fit_transform(labels)
test_preds = le.transform( gt )

# I added this:
class_guess = probs.argmax(dim=1)

# Calculate accuracy
from sklearn.metrics import accuracy_score
acc = accuracy_score( class_guess.numpy(), np.asarray( test_preds ) )
print( "Accuracy = " + str( acc ) )

# Calculate precision per class
print(data.classes)

from sklearn.metrics import precision_score
prec = precision_score( class_guess.numpy(), np.asarray( test_preds ), average=None )
print( "Precision (Positive Predictive Value) per class = " + str( prec ))

# Calculate recall per class
from sklearn.metrics import recall_score
rec = recall_score(class_guess.numpy(), np.asarray(test_preds), average=None )
print( "Recall (Sensitiviy) per class = " + str( rec ))
# Out:
# Accuracy = 0.9430018999366688
# ['COVID-19', 'normal', 'pneumonia']
# Precision (Positive Predictive Value) per class = [0.86     0.963842 0.925926]
# Recall (Sensitiviy) per class = [0.966292 0.944629 0.936968]

# %%
learn.summary
# Out:
# <bound method model_summary of Learner(data=ImageDataBunch;
#
# Train: LabelList (12502 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# normal,normal,normal,normal,pneumonia
# Path: /content/data/train;
#
# Valid: LabelList (1579 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# pneumonia,pneumonia,pneumonia,pneumonia,pneumonia
# Path: /content/data/test;
#
# Test: LabelList (1579 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: EmptyLabelList
# ,,,,
# Path: /content/data/train, model=MXResNet(
#   (0): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Mish()
#   )
#   (1): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Mish()
#   )
#   (2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Mish()
#   )
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (idconv): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): ResBlock(
#       (sa): SimpleSelfAttention(
#         (conv): Conv1d(256, 256, kernel_size=(1,), stride=(1,), bias=False)
#       )
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (5): Sequential(
#     (0): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (idconv): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (1): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (6): Sequential(
#     (0): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (idconv): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (1): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (7): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (8): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (13): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (14): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (15): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (16): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (17): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (18): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (19): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (20): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (21): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (22): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (7): Sequential(
#     (0): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (idconv): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (1): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): ResBlock(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (1): Sequential(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Mish()
#         )
#         (2): Sequential(
#           (0): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=1)
#   (9): Flatten()
#   (10): Linear(in_features=2048, out_features=3, bias=True)
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function error_rate at 0x7fc2dd728d90>, <function accuracy at 0x7fc2dd728b70>, Precision(average='macro', pos_label=1, eps=1e-09), Recall(average='macro', pos_label=1, eps=1e-09)], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('/content/data/train'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False), <class 'fastai.callbacks.oversampling.OverSamplingCallback'>], callbacks=[], layer_groups=[Sequential(
#   (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): Mish()
#   (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): Mish()
#   (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Mish()
#   (9): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (10): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): Mish()
#   (13): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (14): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (15): Mish()
#   (16): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (17): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (18): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (19): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (21): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): Mish()
#   (23): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (24): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (25): Mish()
#   (26): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (27): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (28): Conv1d(256, 256, kernel_size=(1,), stride=(1,), bias=False)
#   (29): ParameterModule()
#   (30): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (31): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (32): Mish()
#   (33): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (34): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (35): Mish()
#   (36): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (37): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (38): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (39): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (40): Mish()
#   (41): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (42): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (43): Mish()
#   (44): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (45): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (46): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (47): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (48): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (49): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (50): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (51): Mish()
#   (52): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (53): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (54): Mish()
#   (55): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (56): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (57): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (58): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (59): Mish()
#   (60): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (61): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (62): Mish()
#   (63): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (64): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (65): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (66): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (67): Mish()
#   (68): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (69): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (70): Mish()
#   (71): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (72): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (73): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (74): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (75): Mish()
#   (76): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (77): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (78): Mish()
#   (79): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (80): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (81): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (82): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (83): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (84): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (85): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (86): Mish()
#   (87): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (88): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (89): Mish()
#   (90): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (91): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (92): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (93): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (94): Mish()
#   (95): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (96): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (97): Mish()
#   (98): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (99): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (100): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (101): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (102): Mish()
#   (103): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (104): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (105): Mish()
#   (106): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (107): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (108): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (109): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (110): Mish()
#   (111): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (112): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (113): Mish()
#   (114): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (115): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (116): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (117): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (118): Mish()
#   (119): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (120): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (121): Mish()
#   (122): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (123): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (124): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (125): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (126): Mish()
#   (127): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (128): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (129): Mish()
#   (130): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (131): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (132): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (133): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (134): Mish()
#   (135): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (136): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (137): Mish()
#   (138): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (139): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (140): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (141): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (142): Mish()
#   (143): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (144): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (145): Mish()
#   (146): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (147): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (148): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (149): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (150): Mish()
#   (151): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (152): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (153): Mish()
#   (154): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (155): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (156): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (157): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (158): Mish()
#   (159): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (160): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (161): Mish()
#   (162): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (163): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (164): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (165): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (166): Mish()
#   (167): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (168): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (169): Mish()
#   (170): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (171): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (172): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (173): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (174): Mish()
#   (175): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (176): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (177): Mish()
#   (178): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (179): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (180): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (181): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (182): Mish()
#   (183): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (184): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (185): Mish()
#   (186): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (187): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (188): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (189): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (190): Mish()
#   (191): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (192): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (193): Mish()
#   (194): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (195): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (196): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (197): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (198): Mish()
#   (199): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (200): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (201): Mish()
#   (202): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (203): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (204): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (205): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (206): Mish()
#   (207): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (208): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (209): Mish()
#   (210): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (211): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (212): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (213): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (214): Mish()
#   (215): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (216): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (217): Mish()
#   (218): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (219): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (220): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (221): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (222): Mish()
#   (223): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (224): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (225): Mish()
#   (226): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (227): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (228): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (229): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (230): Mish()
#   (231): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (232): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (233): Mish()
#   (234): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (235): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (236): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (237): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (238): Mish()
#   (239): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (240): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (241): Mish()
#   (242): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (243): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (244): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (245): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (246): Mish()
#   (247): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (248): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (249): Mish()
#   (250): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (251): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (252): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (253): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (254): Mish()
#   (255): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (256): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (257): Mish()
#   (258): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (259): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (260): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (261): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (262): Mish()
#   (263): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (264): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (265): Mish()
#   (266): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (267): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (268): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (269): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (270): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (271): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (272): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (273): Mish()
#   (274): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (275): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (276): Mish()
#   (277): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (278): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (279): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (280): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (281): Mish()
#   (282): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (283): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (284): Mish()
#   (285): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (286): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (287): AdaptiveAvgPool2d(output_size=1)
#   (288): Flatten()
#   (289): Linear(in_features=2048, out_features=3, bias=True)
# )], add_time=True, silent=False)>

# %% [markdown]
# # Recall, Accuracy, Precision, etc
# https://fr.wikipedia.org/wiki/Pr%C3%A9cision_et_rappel
#
# https://docs.fast.ai/metrics.html
#
# Recall = sensitivity
#
# Precision = Positive predictive value
